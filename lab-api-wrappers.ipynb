# %%
from spotify_client import *
import pandas as pd
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= client_id,
                                                           client_secret= client_secret))

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks = get_playlist_tracks("spotify", "7htu5ftbLBRFAwiuHVcUAg")

# %%
tracks[0]['track']['uri']
# Out:
# 'spotify:track:2MvvoeRt8NcOXWESkxWn3g'

# %%
def features(tracks):
    
    song_features = {}
    
    for i in range(2000):
        song_features[tracks[i]['track']['id']] = sp.audio_features(tracks[i]["track"]["uri"])
    
    return song_features

# %%
sp.audio_features(tracks[0]["track"]["uri"])
# Out:
# [{'danceability': 0.511,
#   'energy': 0.472,
#   'key': 4,
#   'loudness': -9.277,
#   'mode': 1,
#   'speechiness': 0.091,
#   'acousticness': 0.534,
#   'instrumentalness': 0.614,
#   'liveness': 0.11,
#   'valence': 0.0399,
#   'tempo': 127.978,
#   'type': 'audio_features',
#   'id': '2MvvoeRt8NcOXWESkxWn3g',
#   'uri': 'spotify:track:2MvvoeRt8NcOXWESkxWn3g',
#   'track_href': 'https://api.spotify.com/v1/tracks/2MvvoeRt8NcOXWESkxWn3g',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MvvoeRt8NcOXWESkxWn3g',
#   'duration_ms': 258969,
#   'time_signature': 4}]

# %%
features(tracks)
# Out:
# {'2MvvoeRt8NcOXWESkxWn3g': [{'danceability': 0.511,
#    'energy': 0.472,
#    'key': 4,
#    'loudness': -9.277,
#    'mode': 1,
#    'speechiness': 0.091,
#    'acousticness': 0.534,
#    'instrumentalness': 0.614,
#    'liveness': 0.11,
#    'valence': 0.0399,
#    'tempo': 127.978,
#    'type': 'audio_features',
#    'id': '2MvvoeRt8NcOXWESkxWn3g',
#    'uri': 'spotify:track:2MvvoeRt8NcOXWESkxWn3g',
#    'track_href': 'https://api.spotify.com/v1/tracks/2MvvoeRt8NcOXWESkxWn3g',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2MvvoeRt8NcOXWESkxWn3g',
#    'duration_ms': 258969,
#    'time_signature': 4}],
#  '6UFivO2zqqPFPoQYsEMuCc': [{'danceability': 0.742,
#    'energy': 0.546,
#    'key': 1,
#    'loudness': -7.694,
#    'mode': 1,
#    'speechiness': 0.0315,
#    'acousticness': 0.172,
#    'instrumentalness': 0.38,
#    'liveness': 0.115,
#    'valence': 0.868,
#    'tempo': 104.996,
#    'type': 'audio_features',
#    'id': '6UFivO2zqqPFPoQYsEMuCc',
#    'uri': 'spotify:track:6UFivO2zqqPFPoQYsEMuCc',
#    'track_href': 'https://api.spotify.com/v1/tracks/6UFivO2zqqPFPoQYsEMuCc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6UFivO2zqqPFPoQYsEMuCc',
#    'duration_ms': 260520,
#    'time_signature': 4}],
#  '4Musyaro0NM5Awx8b5c627': [{'danceability': 0.609,
#    'energy': 0.629,
#    'key': 10,
#    'loudness': -5.024,
#    'mode': 1,
#    'speechiness': 0.0264,
#    'acousticness': 0.425,
#    'instrumentalness': 0,
#    'liveness': 0.0978,
#    'valence': 0.325,
#    'tempo': 99.955,
#    'type': 'audio_features',
#    'id': '4Musyaro0NM5Awx8b5c627',
#    'uri': 'spotify:track:4Musyaro0NM5Awx8b5c627',
#    'track_href': 'https://api.spotify.com/v1/tracks/4Musyaro0NM5Awx8b5c627',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Musyaro0NM5Awx8b5c627',
#    'duration_ms': 241467,
#    'time_signature': 4}],
#  '1CkvWZme3pRgbzaxZnTl5X': [{'danceability': 0.729,
#    'energy': 0.756,
#    'key': 8,
#    'loudness': -5.119,
#    'mode': 1,
#    'speechiness': 0.0294,
#    'acousticness': 0.131,
#    'instrumentalness': 0,
#    'liveness': 0.0527,
#    'valence': 0.522,
#    'tempo': 104.945,
#    'type': 'audio_features',
#    'id': '1CkvWZme3pRgbzaxZnTl5X',
#    'uri': 'spotify:track:1CkvWZme3pRgbzaxZnTl5X',
#    'track_href': 'https://api.spotify.com/v1/tracks/1CkvWZme3pRgbzaxZnTl5X',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CkvWZme3pRgbzaxZnTl5X',
#    'duration_ms': 228293,
#    'time_signature': 4}],
#  '4lLtanYk6tkMvooU0tWzG8': [{'danceability': 0.706,
#    'energy': 0.558,
#    'key': 2,
#    'loudness': -7.237,
#    'mode': 0,
#    'speechiness': 0.0593,
#    'acousticness': 0.146,
#    'instrumentalness': 0,
#    'liveness': 0.118,
#    'valence': 0.227,
#    'tempo': 110.443,
#    'type': 'audio_features',
#    'id': '4lLtanYk6tkMvooU0tWzG8',
#    'uri': 'spotify:track:4lLtanYk6tkMvooU0tWzG8',
#    'track_href': 'https://api.spotify.com/v1/tracks/4lLtanYk6tkMvooU0tWzG8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4lLtanYk6tkMvooU0tWzG8',
#    'duration_ms': 223253,
#    'time_signature': 4}],
#  '3OT3Kg4jyVkdZm4Ncz6JgX': [{'danceability': 0.848,
#    'energy': 0.828,
#    'key': 8,
#    'loudness': -4.557,
#    'mode': 0,
#    'speechiness': 0.0714,
#    'acousticness': 0.136,
#    'instrumentalness': 1.35e-06,
#    'liveness': 0.114,
#    'valence': 0.794,
#    'tempo': 119.0,
#    'type': 'audio_features',
#    'id': '3OT3Kg4jyVkdZm4Ncz6JgX',
#    'uri': 'spotify:track:3OT3Kg4jyVkdZm4Ncz6JgX',
#    'track_href': 'https://api.spotify.com/v1/tracks/3OT3Kg4jyVkdZm4Ncz6JgX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3OT3Kg4jyVkdZm4Ncz6JgX',
#    'duration_ms': 237213,
#    'time_signature': 4}],
#  '21JTgoZLDB2F4Fx0uRCmTL': [{'danceability': 0.237,
#    'energy': 0.269,
#    'key': 7,
#    'loudness': -9.61,
#    'mode': 0,
#    'speechiness': 0.0298,
#    'acousticness': 0.573,
#    'instrumentalness': 0.000283,
#    'liveness': 0.101,
#    'valence': 0.0681,
#    'tempo': 81.256,
#    'type': 'audio_features',
#    'id': '21JTgoZLDB2F4Fx0uRCmTL',
#    'uri': 'spotify:track:21JTgoZLDB2F4Fx0uRCmTL',
#    'track_href': 'https://api.spotify.com/v1/tracks/21JTgoZLDB2F4Fx0uRCmTL',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/21JTgoZLDB2F4Fx0uRCmTL',
#    'duration_ms': 233480,
#    'time_signature': 4}],
#  '4lCv7b86sLynZbXhfScfm2': [{'danceability': 0.638,
#    'energy': 0.826,
#    'key': 8,
#    'loudness': -4.968,
#    'mode': 1,
#    'speechiness': 0.0479,
#    'acousticness': 0.139,
#    'instrumentalness': 0,
#    'liveness': 0.0803,
#    'valence': 0.649,
#    'tempo': 124.072,
#    'type': 'audio_features',
#    'id': '4lCv7b86sLynZbXhfScfm2',
#    'uri': 'spotify:track:4lCv7b86sLynZbXhfScfm2',
#    'track_href': 'https://api.spotify.com/v1/tracks/4lCv7b86sLynZbXhfScfm2',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4lCv7b86sLynZbXhfScfm2',
#    'duration_ms': 227880,
#    'time_signature': 4}],
#  '3AJwUDP919kvQ9QcozQPxg': [{'danceability': 0.429,
#    'energy': 0.661,
#    'key': 11,
#    'loudness': -7.227,
#    'mode': 1,
#    'speechiness': 0.0281,
#    'acousticness': 0.00239,
#    'instrumentalness': 0.000121,
#    'liveness': 0.234,
#    'valence': 0.285,
#    'tempo': 173.372,
#    'type': 'audio_features',
#    'id': '3AJwUDP919kvQ9QcozQPxg',
#    'uri': 'spotify:track:3AJwUDP919kvQ9QcozQPxg',
#    'track_href': 'https://api.spotify.com/v1/tracks/3AJwUDP919kvQ9QcozQPxg',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3AJwUDP919kvQ9QcozQPxg',
#    'duration_ms': 266773,
#    'time_signature': 4}],
#  '4oa14QBfWRDfJy2agySy0L': [{'danceability': 0.27,
#    'energy': 0.275,
#    'key': 0,
#    'loudness': -10.357,
#    'mode': 1,
#    'speechiness': 0.0356,
#    'acousticness': 0.834,
#    'instrumentalness': 0,
#    'liveness': 0.146,
#    'valence': 0.231,
#    'tempo': 168.964,
#    'type': 'audio_features',
#    'id': '4oa14QBfWRDfJy2agySy0L',
#    'uri': 'spotify:track:4oa14QBfWRDfJy2agySy0L',
#    'track_href': 'https://api.spotify.com/v1/tracks/4oa14QBfWRDfJy2agySy0L',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4oa14QBfWRDfJy2agySy0L',
#    'duration_ms': 232760,
#    'time_signature': 4}],
#  '7CHIJREUYyM7vndBQE6iMy': [{'danceability': 0.676,
#    'energy': 0.807,
#    'key': 5,
#    'loudness': -5.131,
#    'mode': 1,
#    'speechiness': 0.029,
#    'acousticness': 0.0284,
#    'instrumentalness': 0,
#    'liveness': 0.0701,
#    'valence': 0.443,
#    'tempo': 95.956,
#    'type': 'audio_features',
#    'id': '7CHIJREUYyM7vndBQE6iMy',
#    'uri': 'spotify:track:7CHIJREUYyM7vndBQE6iMy',
#    'track_href': 'https://api.spotify.com/v1/tracks/7CHIJREUYyM7vndBQE6iMy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7CHIJREUYyM7vndBQE6iMy',
#    'duration_ms': 232520,
#    'time_signature': 4}],
#  '6l8AiDMKX10Nu2IZJcPb4i': [{'danceability': 0.605,
#    'energy': 0.936,
#    'key': 0,
#    'loudness': -4.025,
#    'mode': 1,
#    'speechiness': 0.0383,
#    'acousticness': 0.00112,
#    'instrumentalness': 8.57e-06,
#    'liveness': 0.194,
#    'valence': 0.764,
#    'tempo': 101.91,
#    'type': 'audio_features',
#    'id': '6l8AiDMKX10Nu2IZJcPb4i',
#    'uri': 'spotify:track:6l8AiDMKX10Nu2IZJcPb4i',
#    'track_href': 'https://api.spotify.com/v1/tracks/6l8AiDMKX10Nu2IZJcPb4i',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6l8AiDMKX10Nu2IZJcPb4i',
#    'duration_ms': 279013,
#    'time_signature': 4}],
#  '1Jx69b09LKTuBQxkEiFfVX': [{'danceability': 0.397,
#    'energy': 0.817,
#    'key': 2,
#    'loudness': -5.495,
#    'mode': 1,
#    'speechiness': 0.042,
#    'acousticness': 0.0966,
#    'instrumentalness': 8.16e-06,
#    'liveness': 0.316,
#    'valence': 0.416,
#    'tempo': 158.004,
#    'type': 'audio_features',
#    'id': '1Jx69b09LKTuBQxkEiFfVX',
#    'uri': 'spotify:track:1Jx69b09LKTuBQxkEiFfVX',
#    'track_href': 'https://api.spotify.com/v1/tracks/1Jx69b09LKTuBQxkEiFfVX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Jx69b09LKTuBQxkEiFfVX',
#    'duration_ms': 266227,
#    'time_signature': 4}],
#  '1y9U1pdI3naKK7sArioECH': [{'danceability': 0.473,
#    'energy': 0.871,
#    'key': 8,
#    'loudness': -4.732,
#    'mode': 1,
#    'speechiness': 0.0668,
#    'acousticness': 0.178,
#    'instrumentalness': 0,
#    'liveness': 0.0584,
#    'valence': 0.578,
#    'tempo': 156.0,
#    'type': 'audio_features',
#    'id': '1y9U1pdI3naKK7sArioECH',
#    'uri': 'spotify:track:1y9U1pdI3naKK7sArioECH',
#    'track_href': 'https://api.spotify.com/v1/tracks/1y9U1pdI3naKK7sArioECH',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1y9U1pdI3naKK7sArioECH',
#    'duration_ms': 224640,
#    'time_signature': 4}],
#  '7bprRkhvOXWmWpqOrEWbXu': [{'danceability': 0.531,
#    'energy': 0.864,
#    'key': 11,
#    'loudness': -2.978,
#    'mode': 1,
#    'speechiness': 0.0433,
#    'acousticness': 0.000105,
#    'instrumentalness': 2.05e-06,
#    'liveness': 0.346,
#    'valence': 0.401,
#    'tempo': 126.02,
#    'type': 'audio_features',
#    'id': '7bprRkhvOXWmWpqOrEWbXu',
#    'uri': 'spotify:track:7bprRkhvOXWmWpqOrEWbXu',
#    'track_href': 'https://api.spotify.com/v1/tracks/7bprRkhvOXWmWpqOrEWbXu',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7bprRkhvOXWmWpqOrEWbXu',
#    'duration_ms': 214520,
#    'time_signature': 4}],
#  '2eaBBVEfoRK4MJYmIAeNw8': [{'danceability': 0.643,
#    'energy': 0.502,
#    'key': 11,
#    'loudness': -6.558,
#    'mode': 1,
#    'speechiness': 0.0392,
#    'acousticness': 0.07,
#    'instrumentalness': 0.0344,
#    'liveness': 0.149,
#    'valence': 0.2,
#    'tempo': 130.018,
#    'type': 'audio_features',
#    'id': '2eaBBVEfoRK4MJYmIAeNw8',
#    'uri': 'spotify:track:2eaBBVEfoRK4MJYmIAeNw8',
#    'track_href': 'https://api.spotify.com/v1/tracks/2eaBBVEfoRK4MJYmIAeNw8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2eaBBVEfoRK4MJYmIAeNw8',
#    'duration_ms': 279960,
#    'time_signature': 4}],
#  '5IyblF777jLZj1vGHG2UD3': [{'danceability': 0.399,
#    'energy': 0.721,
#    'key': 4,
#    'loudness': -5.562,
#    'mode': 0,
#    'speechiness': 0.0523,
#    'acousticness': 0.0621,
#    'instrumentalness': 0.00282,
#    'liveness': 0.278,
#    'valence': 0.113,
#    'tempo': 160.125,
#    'type': 'audio_features',
#    'id': '5IyblF777jLZj1vGHG2UD3',
#    'uri': 'spotify:track:5IyblF777jLZj1vGHG2UD3',
#    'track_href': 'https://api.spotify.com/v1/tracks/5IyblF777jLZj1vGHG2UD3',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5IyblF777jLZj1vGHG2UD3',
#    'duration_ms': 299934,
#    'time_signature': 4}],
#  '3XVBdLihbNbxUwZosxcGuJ': [{'danceability': 0.609,
#    'energy': 0.445,
#    'key': 7,
#    'loudness': -9.129,
#    'mode': 1,
#    'speechiness': 0.106,
#    'acousticness': 0.603,
#    'instrumentalness': 6.77e-06,
#    'liveness': 0.104,
#    'valence': 0.166,
#    'tempo': 118.393,
#    'type': 'audio_features',
#    'id': '3XVBdLihbNbxUwZosxcGuJ',
#    'uri': 'spotify:track:3XVBdLihbNbxUwZosxcGuJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/3XVBdLihbNbxUwZosxcGuJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3XVBdLihbNbxUwZosxcGuJ',
#    'duration_ms': 228707,
#    'time_signature': 3}],
#  '38jy6kRlPt8z1GUS9WXeNh': [{'danceability': 0.573,
#    'energy': 0.454,
#    'key': 3,
#    'loudness': -10.286,
#    'mode': 1,
#    'speechiness': 0.0258,
#    'acousticness': 0.479,
#    'instrumentalness': 1.36e-05,
#    'liveness': 0.0974,
#    'valence': 0.515,
#    'tempo': 140.187,
#    'type': 'audio_features',
#    'id': '38jy6kRlPt8z1GUS9WXeNh',
#    'uri': 'spotify:track:38jy6kRlPt8z1GUS9WXeNh',
#    'track_href': 'https://api.spotify.com/v1/tracks/38jy6kRlPt8z1GUS9WXeNh',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/38jy6kRlPt8z1GUS9WXeNh',
#    'duration_ms': 216387,
#    'time_signature': 4}],
#  '3YPchhrSmcwMHl41aToYG1': [{'danceability': 0.313,
#    'energy': 0.491,
#    'key': 9,
#    'loudness': -7.939,
#    'mode': 1,
#    'speechiness': 0.0387,
#    'acousticness': 0.321,
#    'instrumentalness': 1.82e-06,
#    'liveness': 0.0863,
#    'valence': 0.243,
#    'tempo': 178.262,
#    'type': 'audio_features',
#    'id': '3YPchhrSmcwMHl41aToYG1',
#    'uri': 'spotify:track:3YPchhrSmcwMHl41aToYG1',
#    'track_href': 'https://api.spotify.com/v1/tracks/3YPchhrSmcwMHl41aToYG1',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3YPchhrSmcwMHl41aToYG1',
#    'duration_ms': 255387,
#    'time_signature': 3}],
#  '4u83mwF5tUuWlXS86UOXdu': [{'danceability': 0.384,
#    'energy': 0.527,
#    'key': 11,
#    'loudness': -5.294,
#    'mode': 0,
#    'speechiness': 0.0269,
#    'acousticness': 0.542,
#    'instrumentalness': 0,
#    'liveness': 0.156,
#    'valence': 0.222,
#    'tempo': 100.73,
#    'type': 'audio_features',
#    'id': '4u83mwF5tUuWlXS86UOXdu',
#    'uri': 'spotify:track:4u83mwF5tUuWlXS86UOXdu',
#    'track_href': 'https://api.spotify.com/v1/tracks/4u83mwF5tUuWlXS86UOXdu',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4u83mwF5tUuWlXS86UOXdu',
#    'duration_ms': 221200,
#    'time_signature': 3}],
#  '76N7FdzCI9OsiUnzJVLY2m': [{'danceability': 0.618,
#    'energy': 0.753,
#    'key': 7,
#    'loudness': -5.05,
#    'mode': 0,
#    'speechiness': 0.0451,
#    'acousticness': 0.637,
#    'instrumentalness': 0,
#    'liveness': 0.0905,
#    'valence': 0.557,
#    'tempo': 120.041,
#    'type': 'audio_features',
#    'id': '76N7FdzCI9OsiUnzJVLY2m',
#    'uri': 'spotify:track:76N7FdzCI9OsiUnzJVLY2m',
#    'track_href': 'https://api.spotify.com/v1/tracks/76N7FdzCI9OsiUnzJVLY2m',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/76N7FdzCI9OsiUnzJVLY2m',
#    'duration_ms': 221427,
#    'time_signature': 4}],
#  '4eH8TpawYJMjcDvC0LDHYv': [{'danceability': 0.571,
#    'energy': 0.698,
#    'key': 6,
#    'loudness': -4.747,
#    'mode': 1,
#    'speechiness': 0.0342,
#    'acousticness': 0.00593,
#    'instrumentalness': 0,
#    'liveness': 0.0992,
#    'valence': 0.423,
#    'tempo': 109.867,
#    'type': 'audio_features',
#    'id': '4eH8TpawYJMjcDvC0LDHYv',
#    'uri': 'spotify:track:4eH8TpawYJMjcDvC0LDHYv',
#    'track_href': 'https://api.spotify.com/v1/tracks/4eH8TpawYJMjcDvC0LDHYv',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4eH8TpawYJMjcDvC0LDHYv',
#    'duration_ms': 168667,
#    'time_signature': 4}],
#  '5OGkKx8jP0A5KSULEc6XYZ': [{'danceability': 0.693,
#    'energy': 0.594,
#    'key': 1,
#    'loudness': -6.408,
#    'mode': 1,
#    'speechiness': 0.0325,
#    'acousticness': 0.13,
#    'instrumentalness': 0,
#    'liveness': 0.115,
#    'valence': 0.192,
#    'tempo': 123.932,
#    'type': 'audio_features',
#    'id': '5OGkKx8jP0A5KSULEc6XYZ',
#    'uri': 'spotify:track:5OGkKx8jP0A5KSULEc6XYZ',
#    'track_href': 'https://api.spotify.com/v1/tracks/5OGkKx8jP0A5KSULEc6XYZ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OGkKx8jP0A5KSULEc6XYZ',
#    'duration_ms': 244107,
#    'time_signature': 4}],
#  '66m3eG3ioXCWpP1qDQ4sXt': [{'danceability': 0.725,
#    'energy': 0.672,
#    'key': 5,
#    'loudness': -5.353,
#    'mode': 0,
#    'speechiness': 0.0283,
#    'acousticness': 4.62e-05,
#    'instrumentalness': 0.00225,
#    'liveness': 0.112,
#    'valence': 0.777,
#    'tempo': 125.042,
#    'type': 'audio_features',
#    'id': '66m3eG3ioXCWpP1qDQ4sXt',
#    'uri': 'spotify:track:66m3eG3ioXCWpP1qDQ4sXt',
#    'track_href': 'https://api.spotify.com/v1/tracks/66m3eG3ioXCWpP1qDQ4sXt',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/66m3eG3ioXCWpP1qDQ4sXt',
#    'duration_ms': 215200,
#    'time_signature': 4}],
#  '24cKN8P2uGWypxTw5WaNlq': [{'danceability': 0.64,
#    'energy': 0.395,
#    'key': 3,
#    'loudness': -5.689,
#    'mode': 1,
#    'speechiness': 0.0307,
#    'acousticness': 0.206,
#    'instrumentalness': 0,
#    'liveness': 0.0935,
#    'valence': 0.235,
#    'tempo': 115.082,
#    'type': 'audio_features',
#    'id': '24cKN8P2uGWypxTw5WaNlq',
#    'uri': 'spotify:track:24cKN8P2uGWypxTw5WaNlq',
#    'track_href': 'https://api.spotify.com/v1/tracks/24cKN8P2uGWypxTw5WaNlq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/24cKN8P2uGWypxTw5WaNlq',
#    'duration_ms': 243200,
#    'time_signature': 4}],
#  '5OiLJ8tjUPFiPX2gVM8fxJ': [{'danceability': 0.597,
#    'energy': 0.517,
#    'key': 0,
#    'loudness': -6.963,
#    'mode': 1,
#    'speechiness': 0.365,
#    'acousticness': 0.179,
#    'instrumentalness': 0,
#    'liveness': 0.307,
#    'valence': 0.412,
#    'tempo': 92.035,
#    'type': 'audio_features',
#    'id': '5OiLJ8tjUPFiPX2gVM8fxJ',
#    'uri': 'spotify:track:5OiLJ8tjUPFiPX2gVM8fxJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/5OiLJ8tjUPFiPX2gVM8fxJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OiLJ8tjUPFiPX2gVM8fxJ',
#    'duration_ms': 257560,
#    'time_signature': 4}],
#  '0f19yeMTQ5ygqwUhv46tdN': [{'danceability': 0.671,
#    'energy': 0.909,
#    'key': 10,
#    'loudness': -3.213,
#    'mode': 1,
#    'speechiness': 0.0569,
#    'acousticness': 0.0108,
#    'instrumentalness': 0,
#    'liveness': 0.6,
#    'valence': 0.795,
#    'tempo': 119.97,
#    'type': 'audio_features',
#    'id': '0f19yeMTQ5ygqwUhv46tdN',
#    'uri': 'spotify:track:0f19yeMTQ5ygqwUhv46tdN',
#    'track_href': 'https://api.spotify.com/v1/tracks/0f19yeMTQ5ygqwUhv46tdN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0f19yeMTQ5ygqwUhv46tdN',
#    'duration_ms': 231840,
#    'time_signature': 4}],
#  '0CSTvWUps1YmpQoXXay9ol': [{'danceability': 0.524,
#    'energy': 0.803,
#    'key': 9,
#    'loudness': -5.56,
#    'mode': 0,
#    'speechiness': 0.0366,
#    'acousticness': 0.145,
#    'instrumentalness': 0.000191,
#    'liveness': 0.115,
#    'valence': 0.0827,
#    'tempo': 140.003,
#    'type': 'audio_features',
#    'id': '0CSTvWUps1YmpQoXXay9ol',
#    'uri': 'spotify:track:0CSTvWUps1YmpQoXXay9ol',
#    'track_href': 'https://api.spotify.com/v1/tracks/0CSTvWUps1YmpQoXXay9ol',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0CSTvWUps1YmpQoXXay9ol',
#    'duration_ms': 255133,
#    'time_signature': 4}],
#  '5RqIM2vv5nw2PGJBqPD8Rg': [{'danceability': 0.59,
#    'energy': 0.803,
#    'key': 4,
#    'loudness': -2.518,
#    'mode': 1,
#    'speechiness': 0.085,
#    'acousticness': 0.537,
#    'instrumentalness': 0,
#    'liveness': 0.105,
#    'valence': 0.477,
#    'tempo': 87.851,
#    'type': 'audio_features',
#    'id': '5RqIM2vv5nw2PGJBqPD8Rg',
#    'uri': 'spotify:track:5RqIM2vv5nw2PGJBqPD8Rg',
#    'track_href': 'https://api.spotify.com/v1/tracks/5RqIM2vv5nw2PGJBqPD8Rg',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RqIM2vv5nw2PGJBqPD8Rg',
#    'duration_ms': 151573,
#    'time_signature': 4}],
#  '6SKwQghsR8AISlxhcwyA9R': [{'danceability': 0.62,
#    'energy': 0.832,
#    'key': 10,
#    'loudness': -4.848,
#    'mode': 1,
#    'speechiness': 0.036,
#    'acousticness': 0.332,
#    'instrumentalness': 0,
#    'liveness': 0.104,
#    'valence': 0.481,
#    'tempo': 144.926,
#    'type': 'audio_features',
#    'id': '6SKwQghsR8AISlxhcwyA9R',
#    'uri': 'spotify:track:6SKwQghsR8AISlxhcwyA9R',
#    'track_href': 'https://api.spotify.com/v1/tracks/6SKwQghsR8AISlxhcwyA9R',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6SKwQghsR8AISlxhcwyA9R',
#    'duration_ms': 230120,
#    'time_signature': 4}],
#  '0C4ejWmOTMv8vuYj85mf8m': [{'danceability': 0.767,
#    'energy': 0.682,
#    'key': 1,
#    'loudness': -5.02,
#    'mode': 1,
#    'speechiness': 0.042,
#    'acousticness': 0.0113,
#    'instrumentalness': 0.00016,
#    'liveness': 0.104,
#    'valence': 0.833,
#    'tempo': 127.975,
#    'type': 'audio_features',
#    'id': '0C4ejWmOTMv8vuYj85mf8m',
#    'uri': 'spotify:track:0C4ejWmOTMv8vuYj85mf8m',
#    'track_href': 'https://api.spotify.com/v1/tracks/0C4ejWmOTMv8vuYj85mf8m',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0C4ejWmOTMv8vuYj85mf8m',
#    'duration_ms': 243533,
#    'time_signature': 4}],
#  '6pEU943aHfZdY4jhUpQ9ms': [{'danceability': 0.534,
#    'energy': 0.855,
#    'key': 4,
#    'loudness': -7.102,
#    'mode': 0,
#    'speechiness': 0.0526,
#    'acousticness': 0.00706,
#    'instrumentalness': 0,
#    'liveness': 0.122,
#    'valence': 0.391,
#    'tempo': 95.274,
#    'type': 'audio_features',
#    'id': '6pEU943aHfZdY4jhUpQ9ms',
#    'uri': 'spotify:track:6pEU943aHfZdY4jhUpQ9ms',
#    'track_href': 'https://api.spotify.com/v1/tracks/6pEU943aHfZdY4jhUpQ9ms',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6pEU943aHfZdY4jhUpQ9ms',
#    'duration_ms': 295893,
#    'time_signature': 4}],
#  '5Pmna8kN9EEosmkV5AnEXF': [{'danceability': 0.613,
#    'energy': 0.735,
#    'key': 1,
#    'loudness': -5.094,
#    'mode': 1,
#    'speechiness': 0.0474,
#    'acousticness': 0.378,
#    'instrumentalness': 0,
#    'liveness': 0.104,
#    'valence': 0.326,
#    'tempo': 114.922,
#    'type': 'audio_features',
#    'id': '5Pmna8kN9EEosmkV5AnEXF',
#    'uri': 'spotify:track:5Pmna8kN9EEosmkV5AnEXF',
#    'track_href': 'https://api.spotify.com/v1/tracks/5Pmna8kN9EEosmkV5AnEXF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Pmna8kN9EEosmkV5AnEXF',
#    'duration_ms': 188440,
#    'time_signature': 4}],
#  '3f3omU8n47Mqyab5nCaGyT': [{'danceability': 0.583,
#    'energy': 0.584,
#    'key': 5,
#    'loudness': -5.362,
#    'mode': 0,
#    'speechiness': 0.0314,
#    'acousticness': 0.254,
#    'instrumentalness': 0,
#    'liveness': 0.123,
#    'valence': 0.136,
#    'tempo': 140.039,
#    'type': 'audio_features',
#    'id': '3f3omU8n47Mqyab5nCaGyT',
#    'uri': 'spotify:track:3f3omU8n47Mqyab5nCaGyT',
#    'track_href': 'https://api.spotify.com/v1/tracks/3f3omU8n47Mqyab5nCaGyT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3f3omU8n47Mqyab5nCaGyT',
#    'duration_ms': 219493,
#    'time_signature': 4}],
#  '4AboqNl74jNDpJhPfqYDmj': [{'danceability': 0.829,
#    'energy': 0.607,
#    'key': 1,
#    'loudness': -3.876,
#    'mode': 1,
#    'speechiness': 0.0897,
#    'acousticness': 0.0049,
#    'instrumentalness': 0,
#    'liveness': 0.0986,
#    'valence': 0.766,
#    'tempo': 120.044,
#    'type': 'audio_features',
#    'id': '4AboqNl74jNDpJhPfqYDmj',
#    'uri': 'spotify:track:4AboqNl74jNDpJhPfqYDmj',
#    'track_href': 'https://api.spotify.com/v1/tracks/4AboqNl74jNDpJhPfqYDmj',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AboqNl74jNDpJhPfqYDmj',
#    'duration_ms': 187067,
#    'time_signature': 4}],
#  '1FbTceMivK92mVV3iGdwZk': [{'danceability': 0.587,
#    'energy': 0.738,
#    'key': 7,
#    'loudness': -4.469,
#    'mode': 1,
#    'speechiness': 0.0282,
#    'acousticness': 0.548,
#    'instrumentalness': 0,
#    'liveness': 0.109,
#    'valence': 0.329,
#    'tempo': 99.046,
#    'type': 'audio_features',
#    'id': '1FbTceMivK92mVV3iGdwZk',
#    'uri': 'spotify:track:1FbTceMivK92mVV3iGdwZk',
#    'track_href': 'https://api.spotify.com/v1/tracks/1FbTceMivK92mVV3iGdwZk',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FbTceMivK92mVV3iGdwZk',
#    'duration_ms': 225933,
#    'time_signature': 4}],
#  '3Y1JP1ulhlpgCqRzMQhVJr': [{'danceability': 0.363,
#    'energy': 0.355,
#    'key': 7,
#    'loudness': -9.877,
#    'mode': 1,
#    'speechiness': 0.0457,
#    'acousticness': 0.371,
#    'instrumentalness': 7.43e-05,
#    'liveness': 0.0814,
#    'valence': 0.19,
#    'tempo': 180.364,
#    'type': 'audio_features',
#    'id': '3Y1JP1ulhlpgCqRzMQhVJr',
#    'uri': 'spotify:track:3Y1JP1ulhlpgCqRzMQhVJr',
#    'track_href': 'https://api.spotify.com/v1/tracks/3Y1JP1ulhlpgCqRzMQhVJr',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Y1JP1ulhlpgCqRzMQhVJr',
#    'duration_ms': 266533,
#    'time_signature': 4}],
#  '0Cvjlph1WGbwZY1PlMEtJY': [{'danceability': 0.363,
#    'energy': 0.129,
#    'key': 0,
#    'loudness': -14.304,
#    'mode': 1,
#    'speechiness': 0.0322,
#    'acousticness': 0.904,
#    'instrumentalness': 1.52e-06,
#    'liveness': 0.157,
#    'valence': 0.147,
#    'tempo': 80.367,
#    'type': 'audio_features',
#    'id': '0Cvjlph1WGbwZY1PlMEtJY',
#    'uri': 'spotify:track:0Cvjlph1WGbwZY1PlMEtJY',
#    'track_href': 'https://api.spotify.com/v1/tracks/0Cvjlph1WGbwZY1PlMEtJY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Cvjlph1WGbwZY1PlMEtJY',
#    'duration_ms': 198147,
#    'time_signature': 3}],
#  '1zusIxNqJu8i4g6P6hJ2Qa': [{'danceability': 0.793,
#    'energy': 0.859,
#    'key': 0,
#    'loudness': -3.774,
#    'mode': 1,
#    'speechiness': 0.0332,
#    'acousticness': 0.266,
#    'instrumentalness': 0.000356,
#    'liveness': 0.133,
#    'valence': 0.964,
#    'tempo': 129.911,
#    'type': 'audio_features',
#    'id': '1zusIxNqJu8i4g6P6hJ2Qa',
#    'uri': 'spotify:track:1zusIxNqJu8i4g6P6hJ2Qa',
#    'track_href': 'https://api.spotify.com/v1/tracks/1zusIxNqJu8i4g6P6hJ2Qa',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zusIxNqJu8i4g6P6hJ2Qa',
#    'duration_ms': 219920,
#    'time_signature': 4}],
#  '0NZx7rRyIOArlTbRbM3efn': [{'danceability': 0.433,
#    'energy': 0.361,
#    'key': 6,
#    'loudness': -7.679,
#    'mode': 0,
#    'speechiness': 0.0298,
#    'acousticness': 0.609,
#    'instrumentalness': 0.00565,
#    'liveness': 0.177,
#    'valence': 0.102,
#    'tempo': 119.53,
#    'type': 'audio_features',
#    'id': '0NZx7rRyIOArlTbRbM3efn',
#    'uri': 'spotify:track:0NZx7rRyIOArlTbRbM3efn',
#    'track_href': 'https://api.spotify.com/v1/tracks/0NZx7rRyIOArlTbRbM3efn',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0NZx7rRyIOArlTbRbM3efn',
#    'duration_ms': 226133,
#    'time_signature': 3}],
#  '5u0YB9bpmgEPS2bPhwfRFV': [{'danceability': 0.463,
#    'energy': 0.755,
#    'key': 4,
#    'loudness': -7.244,
#    'mode': 1,
#    'speechiness': 0.0634,
#    'acousticness': 0.11,
#    'instrumentalness': 4.89e-06,
#    'liveness': 0.103,
#    'valence': 0.252,
#    'tempo': 145.319,
#    'type': 'audio_features',
#    'id': '5u0YB9bpmgEPS2bPhwfRFV',
#    'uri': 'spotify:track:5u0YB9bpmgEPS2bPhwfRFV',
#    'track_href': 'https://api.spotify.com/v1/tracks/5u0YB9bpmgEPS2bPhwfRFV',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5u0YB9bpmgEPS2bPhwfRFV',
#    'duration_ms': 261213,
#    'time_signature': 4}],
#  '3VA8T3rNy5V24AXxNK5u9E': [{'danceability': 0.676,
#    'energy': 0.762,
#    'key': 1,
#    'loudness': -4.172,
#    'mode': 1,
#    'speechiness': 0.0351,
#    'acousticness': 0.461,
#    'instrumentalness': 0,
#    'liveness': 0.0574,
#    'valence': 0.81,
#    'tempo': 119.003,
#    'type': 'audio_features',
#    'id': '3VA8T3rNy5V24AXxNK5u9E',
#    'uri': 'spotify:track:3VA8T3rNy5V24AXxNK5u9E',
#    'track_href': 'https://api.spotify.com/v1/tracks/3VA8T3rNy5V24AXxNK5u9E',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3VA8T3rNy5V24AXxNK5u9E',
#    'duration_ms': 207493,
#    'time_signature': 4}],
#  '4I3KMa9p00MJwWbT0vi5iX': [{'danceability': 0.464,
#    'energy': 0.467,
#    'key': 5,
#    'loudness': -5.306,
#    'mode': 1,
#    'speechiness': 0.0376,
#    'acousticness': 0.295,
#    'instrumentalness': 0,
#    'liveness': 0.141,
#    'valence': 0.169,
#    'tempo': 51.66,
#    'type': 'audio_features',
#    'id': '4I3KMa9p00MJwWbT0vi5iX',
#    'uri': 'spotify:track:4I3KMa9p00MJwWbT0vi5iX',
#    'track_href': 'https://api.spotify.com/v1/tracks/4I3KMa9p00MJwWbT0vi5iX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4I3KMa9p00MJwWbT0vi5iX',
#    'duration_ms': 346813,
#    'time_signature': 4}],
#  '5zF2zGPkL6Ipsn9AfAK6RP': [{'danceability': 0.714,
#    'energy': 0.868,
#    'key': 5,
#    'loudness': -4.596,
#    'mode': 0,
#    'speechiness': 0.0363,
#    'acousticness': 0.0551,
#    'instrumentalness': 0,
#    'liveness': 0.0987,
#    'valence': 0.78,
#    'tempo': 95.05,
#    'type': 'audio_features',
#    'id': '5zF2zGPkL6Ipsn9AfAK6RP',
#    'uri': 'spotify:track:5zF2zGPkL6Ipsn9AfAK6RP',
#    'track_href': 'https://api.spotify.com/v1/tracks/5zF2zGPkL6Ipsn9AfAK6RP',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zF2zGPkL6Ipsn9AfAK6RP',
#    'duration_ms': 206200,
#    'time_signature': 4}],
#  '23g4kW38gB9f5wu96DLudy': [{'danceability': 0.694,
#    'energy': 0.523,
#    'key': 2,
#    'loudness': -6.407,
#    'mode': 0,
#    'speechiness': 0.0254,
#    'acousticness': 0.875,
#    'instrumentalness': 0.000172,
#    'liveness': 0.352,
#    'valence': 0.472,
#    'tempo': 97.985,
#    'type': 'audio_features',
#    'id': '23g4kW38gB9f5wu96DLudy',
#    'uri': 'spotify:track:23g4kW38gB9f5wu96DLudy',
#    'track_href': 'https://api.spotify.com/v1/tracks/23g4kW38gB9f5wu96DLudy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23g4kW38gB9f5wu96DLudy',
#    'duration_ms': 209453,
#    'time_signature': 4}],
#  '6YdF6J3rz1BX6AZVhe7zgL': [{'danceability': 0.152,
#    'energy': 0.334,
#    'key': 7,
#    'loudness': -4.735,
#    'mode': 1,
#    'speechiness': 0.0306,
#    'acousticness': 0.639,
#    'instrumentalness': 6.95e-05,
#    'liveness': 0.115,
#    'valence': 0.161,
#    'tempo': 71.728,
#    'type': 'audio_features',
#    'id': '6YdF6J3rz1BX6AZVhe7zgL',
#    'uri': 'spotify:track:6YdF6J3rz1BX6AZVhe7zgL',
#    'track_href': 'https://api.spotify.com/v1/tracks/6YdF6J3rz1BX6AZVhe7zgL',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6YdF6J3rz1BX6AZVhe7zgL',
#    'duration_ms': 215867,
#    'time_signature': 4}],
#  '0ygAYQQy7bfDN6gH640bbl': [{'danceability': 0.616,
#    'energy': 0.209,
#    'key': 9,
#    'loudness': -13.43,
#    'mode': 1,
#    'speechiness': 0.406,
#    'acousticness': 0.902,
#    'instrumentalness': 0,
#    'liveness': 0.139,
#    'valence': 0.336,
#    'tempo': 86.891,
#    'type': 'audio_features',
#    'id': '0ygAYQQy7bfDN6gH640bbl',
#    'uri': 'spotify:track:0ygAYQQy7bfDN6gH640bbl',
#    'track_href': 'https://api.spotify.com/v1/tracks/0ygAYQQy7bfDN6gH640bbl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ygAYQQy7bfDN6gH640bbl',
#    'duration_ms': 229613,
#    'time_signature': 1}],
#  '5vGEdM7LvbgMypJkILhQ4p': [{'danceability': 0.494,
#    'energy': 0.831,
#    'key': 7,
#    'loudness': -5.151,
#    'mode': 1,
#    'speechiness': 0.0996,
#    'acousticness': 0.0363,
#    'instrumentalness': 0.00345,
#    'liveness': 0.119,
#    'valence': 0.271,
#    'tempo': 150.248,
#    'type': 'audio_features',
#    'id': '5vGEdM7LvbgMypJkILhQ4p',
#    'uri': 'spotify:track:5vGEdM7LvbgMypJkILhQ4p',
#    'track_href': 'https://api.spotify.com/v1/tracks/5vGEdM7LvbgMypJkILhQ4p',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5vGEdM7LvbgMypJkILhQ4p',
#    'duration_ms': 252819,
#    'time_signature': 4}],
#  '02XnQdf7sipaKBBHixz3Zp': [{'danceability': 0.762,
#    'energy': 0.692,
#    'key': 5,
#    'loudness': -3.973,
#    'mode': 0,
#    'speechiness': 0.0438,
#    'acousticness': 0.113,
#    'instrumentalness': 0,
#    'liveness': 0.094,
#    'valence': 0.397,
#    'tempo': 114.906,
#    'type': 'audio_features',
#    'id': '02XnQdf7sipaKBBHixz3Zp',
#    'uri': 'spotify:track:02XnQdf7sipaKBBHixz3Zp',
#    'track_href': 'https://api.spotify.com/v1/tracks/02XnQdf7sipaKBBHixz3Zp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/02XnQdf7sipaKBBHixz3Zp',
#    'duration_ms': 208307,
#    'time_signature': 4}],
#  '4RL77hMWUq35NYnPLXBpih': [{'danceability': 0.379,
#    'energy': 0.29,
#    'key': 4,
#    'loudness': -8.485,
#    'mode': 1,
#    'speechiness': 0.051,
#    'acousticness': 0.952,
#    'instrumentalness': 0.00106,
#    'liveness': 0.118,
#    'valence': 0.169,
#    'tempo': 166.467,
#    'type': 'audio_features',
#    'id': '4RL77hMWUq35NYnPLXBpih',
#    'uri': 'spotify:track:4RL77hMWUq35NYnPLXBpih',
#    'track_href': 'https://api.spotify.com/v1/tracks/4RL77hMWUq35NYnPLXBpih',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RL77hMWUq35NYnPLXBpih',
#    'duration_ms': 201080,
#    'time_signature': 4}],
#  '6tS3XVuOyu10897O3ae7bi': [{'danceability': 0.791,
#    'energy': 0.754,
#    'key': 0,
#    'loudness': -3.729,
#    'mode': 1,
#    'speechiness': 0.0569,
#    'acousticness': 0.00446,
#    'instrumentalness': 0,
#    'liveness': 0.163,
#    'valence': 0.425,
#    'tempo': 125.014,
#    'type': 'audio_features',
#    'id': '6tS3XVuOyu10897O3ae7bi',
#    'uri': 'spotify:track:6tS3XVuOyu10897O3ae7bi',
#    'track_href': 'https://api.spotify.com/v1/tracks/6tS3XVuOyu10897O3ae7bi',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6tS3XVuOyu10897O3ae7bi',
#    'duration_ms': 234653,
#    'time_signature': 4}],
#  '61xvgZVz1DiR628nmGtsZH': [{'danceability': 0.765,
#    'energy': 0.486,
#    'key': 7,
#    'loudness': -13.819,
#    'mode': 1,
#    'speechiness': 0.0469,
#    'acousticness': 0.0745,
#    'instrumentalness': 9.89e-06,
#    'liveness': 0.282,
#    'valence': 0.856,
#    'tempo': 87.054,
#    'type': 'audio_features',
#    'id': '61xvgZVz1DiR628nmGtsZH',
#    'uri': 'spotify:track:61xvgZVz1DiR628nmGtsZH',
#    'track_href': 'https://api.spotify.com/v1/tracks/61xvgZVz1DiR628nmGtsZH',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/61xvgZVz1DiR628nmGtsZH',
#    'duration_ms': 234507,
#    'time_signature': 4}],
#  '1inG2cgfeGVBsTCcmMIv0e': [{'danceability': 0.629,
#    'energy': 0.969,
#    'key': 8,
#    'loudness': -0.276,
#    'mode': 0,
#    'speechiness': 0.0455,
#    'acousticness': 0.00184,
#    'instrumentalness': 0,
#    'liveness': 0.122,
#    'valence': 0.905,
#    'tempo': 150.01,
#    'type': 'audio_features',
#    'id': '1inG2cgfeGVBsTCcmMIv0e',
#    'uri': 'spotify:track:1inG2cgfeGVBsTCcmMIv0e',
#    'track_href': 'https://api.spotify.com/v1/tracks/1inG2cgfeGVBsTCcmMIv0e',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1inG2cgfeGVBsTCcmMIv0e',
#    'duration_ms': 248627,
#    'time_signature': 4}],
#  '0Uc9PhfV2oP7mhXlLux6SM': [{'danceability': 0.611,
#    'energy': 0.609,
#    'key': 2,
#    'loudness': -7.486,
#    'mode': 1,
#    'speechiness': 0.0308,
#    'acousticness': 0.0767,
#    'instrumentalness': 1.14e-06,
#    'liveness': 0.105,
#    'valence': 0.271,
#    'tempo': 118.997,
#    'type': 'audio_features',
#    'id': '0Uc9PhfV2oP7mhXlLux6SM',
#    'uri': 'spotify:track:0Uc9PhfV2oP7mhXlLux6SM',
#    'track_href': 'https://api.spotify.com/v1/tracks/0Uc9PhfV2oP7mhXlLux6SM',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Uc9PhfV2oP7mhXlLux6SM',
#    'duration_ms': 234213,
#    'time_signature': 4}],
#  '7cvkXf3AwPGT041PyOi5VX': [{'danceability': 0.616,
#    'energy': 0.78,
#    'key': 2,
#    'loudness': -6.062,
#    'mode': 1,
#    'speechiness': 0.0623,
#    'acousticness': 0.0322,
#    'instrumentalness': 0,
#    'liveness': 0.173,
#    'valence': 0.471,
#    'tempo': 110.005,
#    'type': 'audio_features',
#    'id': '7cvkXf3AwPGT041PyOi5VX',
#    'uri': 'spotify:track:7cvkXf3AwPGT041PyOi5VX',
#    'track_href': 'https://api.spotify.com/v1/tracks/7cvkXf3AwPGT041PyOi5VX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7cvkXf3AwPGT041PyOi5VX',
#    'duration_ms': 377467,
#    'time_signature': 4}],
#  '13ETkZ90sElK5xJuB4cUEt': [{'danceability': 0.575,
#    'energy': 0.821,
#    'key': 0,
#    'loudness': -5.7,
#    'mode': 1,
#    'speechiness': 0.0527,
#    'acousticness': 0.181,
#    'instrumentalness': 0,
#    'liveness': 0.124,
#    'valence': 0.449,
#    'tempo': 118.021,
#    'type': 'audio_features',
#    'id': '13ETkZ90sElK5xJuB4cUEt',
#    'uri': 'spotify:track:13ETkZ90sElK5xJuB4cUEt',
#    'track_href': 'https://api.spotify.com/v1/tracks/13ETkZ90sElK5xJuB4cUEt',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/13ETkZ90sElK5xJuB4cUEt',
#    'duration_ms': 238000,
#    'time_signature': 4}],
#  '1EzrEOXmMH3G43AXT1y7pA': [{'danceability': 0.686,
#    'energy': 0.457,
#    'key': 11,
#    'loudness': -8.322,
#    'mode': 1,
#    'speechiness': 0.0468,
#    'acousticness': 0.595,
#    'instrumentalness': 0,
#    'liveness': 0.105,
#    'valence': 0.718,
#    'tempo': 150.953,
#    'type': 'audio_features',
#    'id': '1EzrEOXmMH3G43AXT1y7pA',
#    'uri': 'spotify:track:1EzrEOXmMH3G43AXT1y7pA',
#    'track_href': 'https://api.spotify.com/v1/tracks/1EzrEOXmMH3G43AXT1y7pA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1EzrEOXmMH3G43AXT1y7pA',
#    'duration_ms': 242187,
#    'time_signature': 4}],
#  '1wkcHasramB3g0cPOgos6l': [{'danceability': 0.715,
#    'energy': 0.913,
#    'key': 7,
#    'loudness': -6.07,
#    'mode': 0,
#    'speechiness': 0.0942,
#    'acousticness': 0.0163,
#    'instrumentalness': 7.66e-05,
#    'liveness': 0.418,
#    'valence': 0.813,
#    'tempo': 124.99,
#    'type': 'audio_features',
#    'id': '1wkcHasramB3g0cPOgos6l',
#    'uri': 'spotify:track:1wkcHasramB3g0cPOgos6l',
#    'track_href': 'https://api.spotify.com/v1/tracks/1wkcHasramB3g0cPOgos6l',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wkcHasramB3g0cPOgos6l',
#    'duration_ms': 269253,
#    'time_signature': 4}],
#  '6yocQ10dbs29BUOhoyXpwW': [{'danceability': 0.526,
#    'energy': 0.491,
#    'key': 0,
#    'loudness': -9.076,
#    'mode': 1,
#    'speechiness': 0.0332,
#    'acousticness': 0.0412,
#    'instrumentalness': 0.000217,
#    'liveness': 0.118,
#    'valence': 0.186,
#    'tempo': 67.469,
#    'type': 'audio_features',
#    'id': '6yocQ10dbs29BUOhoyXpwW',
#    'uri': 'spotify:track:6yocQ10dbs29BUOhoyXpwW',
#    'track_href': 'https://api.spotify.com/v1/tracks/6yocQ10dbs29BUOhoyXpwW',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yocQ10dbs29BUOhoyXpwW',
#    'duration_ms': 270640,
#    'time_signature': 4}],
#  '386RUes7n1uM1yfzgeUuwp': [{'danceability': 0.738,
#    'energy': 0.804,
#    'key': 11,
#    'loudness': -3.851,
#    'mode': 1,
#    'speechiness': 0.0621,
#    'acousticness': 0.332,
#    'instrumentalness': 0,
#    'liveness': 0.279,
#    'valence': 0.949,
#    'tempo': 174.943,
#    'type': 'audio_features',
#    'id': '386RUes7n1uM1yfzgeUuwp',
#    'uri': 'spotify:track:386RUes7n1uM1yfzgeUuwp',
#    'track_href': 'https://api.spotify.com/v1/tracks/386RUes7n1uM1yfzgeUuwp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/386RUes7n1uM1yfzgeUuwp',
#    'duration_ms': 190213,
#    'time_signature': 4}],
#  '7LVHVU3tWfcxj5aiPFEW4Q': [{'danceability': 0.209,
#    'energy': 0.417,
#    'key': 3,
#    'loudness': -8.74,
#    'mode': 1,
#    'speechiness': 0.0338,
#    'acousticness': 0.164,
#    'instrumentalness': 0.00196,
#    'liveness': 0.113,
#    'valence': 0.124,
#    'tempo': 138.178,
#    'type': 'audio_features',
#    'id': '7LVHVU3tWfcxj5aiPFEW4Q',
#    'uri': 'spotify:track:7LVHVU3tWfcxj5aiPFEW4Q',
#    'track_href': 'https://api.spotify.com/v1/tracks/7LVHVU3tWfcxj5aiPFEW4Q',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7LVHVU3tWfcxj5aiPFEW4Q',
#    'duration_ms': 295533,
#    'time_signature': 4}],
#  '7xyvMaJZA7thwtPQv6OCbc': [{'danceability': 0.634,
#    'energy': 0.941,
#    'key': 8,
#    'loudness': -6.103,
#    'mode': 1,
#    'speechiness': 0.0337,
#    'acousticness': 0.000297,
#    'instrumentalness': 0.000193,
#    'liveness': 0.114,
#    'valence': 0.793,
#    'tempo': 99.961,
#    'type': 'audio_features',
#    'id': '7xyvMaJZA7thwtPQv6OCbc',
#    'uri': 'spotify:track:7xyvMaJZA7thwtPQv6OCbc',
#    'track_href': 'https://api.spotify.com/v1/tracks/7xyvMaJZA7thwtPQv6OCbc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7xyvMaJZA7thwtPQv6OCbc',
#    'duration_ms': 246027,
#    'time_signature': 4}],
#  '4IMBnBRqm9RALmLrRqfMor': [{'danceability': 0.48,
#    'energy': 0.561,
#    'key': 0,
#    'loudness': -5.874,
#    'mode': 1,
#    'speechiness': 0.027,
#    'acousticness': 0.317,
#    'instrumentalness': 0.00641,
#    'liveness': 0.184,
#    'valence': 0.541,
#    'tempo': 164.791,
#    'type': 'audio_features',
#    'id': '4IMBnBRqm9RALmLrRqfMor',
#    'uri': 'spotify:track:4IMBnBRqm9RALmLrRqfMor',
#    'track_href': 'https://api.spotify.com/v1/tracks/4IMBnBRqm9RALmLrRqfMor',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4IMBnBRqm9RALmLrRqfMor',
#    'duration_ms': 154160,
#    'time_signature': 4}],
#  '4AAF8cbjVMBt7Y6eWqkPZz': [{'danceability': 0.641,
#    'energy': 0.861,
#    'key': 4,
#    'loudness': -5.206,
#    'mode': 1,
#    'speechiness': 0.0285,
#    'acousticness': 0.204,
#    'instrumentalness': 0,
#    'liveness': 0.109,
#    'valence': 0.54,
#    'tempo': 117.044,
#    'type': 'audio_features',
#    'id': '4AAF8cbjVMBt7Y6eWqkPZz',
#    'uri': 'spotify:track:4AAF8cbjVMBt7Y6eWqkPZz',
#    'track_href': 'https://api.spotify.com/v1/tracks/4AAF8cbjVMBt7Y6eWqkPZz',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AAF8cbjVMBt7Y6eWqkPZz',
#    'duration_ms': 217240,
#    'time_signature': 4}],
#  '4peOU5pRQ3wpjofMSXGShR': [{'danceability': 0.56,
#    'energy': 0.652,
#    'key': 5,
#    'loudness': -2.205,
#    'mode': 0,
#    'speechiness': 0.0328,
#    'acousticness': 0.743,
#    'instrumentalness': 0,
#    'liveness': 0.488,
#    'valence': 0.611,
#    'tempo': 86.993,
#    'type': 'audio_features',
#    'id': '4peOU5pRQ3wpjofMSXGShR',
#    'uri': 'spotify:track:4peOU5pRQ3wpjofMSXGShR',
#    'track_href': 'https://api.spotify.com/v1/tracks/4peOU5pRQ3wpjofMSXGShR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4peOU5pRQ3wpjofMSXGShR',
#    'duration_ms': 198093,
#    'time_signature': 4}],
#  '6l2Q66TlfZqzbRkFrZOMT1': [{'danceability': 0.667,
#    'energy': 0.902,
#    'key': 7,
#    'loudness': -4.588,
#    'mode': 1,
#    'speechiness': 0.0988,
#    'acousticness': 0.00112,
#    'instrumentalness': 0,
#    'liveness': 0.0624,
#    'valence': 0.719,
#    'tempo': 135.933,
#    'type': 'audio_features',
#    'id': '6l2Q66TlfZqzbRkFrZOMT1',
#    'uri': 'spotify:track:6l2Q66TlfZqzbRkFrZOMT1',
#    'track_href': 'https://api.spotify.com/v1/tracks/6l2Q66TlfZqzbRkFrZOMT1',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6l2Q66TlfZqzbRkFrZOMT1',
#    'duration_ms': 161973,
#    'time_signature': 4}],
#  '455AfCsOhhLPRc68sE01D8': [{'danceability': 0.649,
#    'energy': 0.815,
#    'key': 3,
#    'loudness': -3.796,
#    'mode': 0,
#    'speechiness': 0.0415,
#    'acousticness': 0.00125,
#    'instrumentalness': 4.31e-05,
#    'liveness': 0.671,
#    'valence': 0.765,
#    'tempo': 126.03,
#    'type': 'audio_features',
#    'id': '455AfCsOhhLPRc68sE01D8',
#    'uri': 'spotify:track:455AfCsOhhLPRc68sE01D8',
#    'track_href': 'https://api.spotify.com/v1/tracks/455AfCsOhhLPRc68sE01D8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/455AfCsOhhLPRc68sE01D8',
#    'duration_ms': 230747,
#    'time_signature': 4}],
#  '0Tel1fmuCxEFV6wBLXsEdk': [{'danceability': 0.589,
#    'energy': 0.227,
#    'key': 2,
#    'loudness': -16.67,
#    'mode': 1,
#    'speechiness': 0.0498,
#    'acousticness': 0.64,
#    'instrumentalness': 0.00469,
#    'liveness': 0.0248,
#    'valence': 0.182,
#    'tempo': 74.993,
#    'type': 'audio_features',
#    'id': '0Tel1fmuCxEFV6wBLXsEdk',
#    'uri': 'spotify:track:0Tel1fmuCxEFV6wBLXsEdk',
#    'track_href': 'https://api.spotify.com/v1/tracks/0Tel1fmuCxEFV6wBLXsEdk',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0Tel1fmuCxEFV6wBLXsEdk',
#    'duration_ms': 280853,
#    'time_signature': 4}],
#  '0BCPKOYdS2jbQ8iyB56Zns': [{'danceability': 0.577,
#    'energy': 0.749,
#    'key': 5,
#    'loudness': -7.215,
#    'mode': 0,
#    'speechiness': 0.0279,
#    'acousticness': 0.599,
#    'instrumentalness': 0.0115,
#    'liveness': 0.183,
#    'valence': 0.255,
#    'tempo': 130.97,
#    'type': 'audio_features',
#    'id': '0BCPKOYdS2jbQ8iyB56Zns',
#    'uri': 'spotify:track:0BCPKOYdS2jbQ8iyB56Zns',
#    'track_href': 'https://api.spotify.com/v1/tracks/0BCPKOYdS2jbQ8iyB56Zns',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0BCPKOYdS2jbQ8iyB56Zns',
#    'duration_ms': 307880,
#    'time_signature': 4}],
#  '5jaz6aiRknA63NIYWdbr2O': [{'danceability': 0.739,
#    'energy': 0.818,
#    'key': 8,
#    'loudness': -5.062,
#    'mode': 1,
#    'speechiness': 0.0418,
#    'acousticness': 0.008,
#    'instrumentalness': 0.00504,
#    'liveness': 0.164,
#    'valence': 0.713,
#    'tempo': 119.982,
#    'type': 'audio_features',
#    'id': '5jaz6aiRknA63NIYWdbr2O',
#    'uri': 'spotify:track:5jaz6aiRknA63NIYWdbr2O',
#    'track_href': 'https://api.spotify.com/v1/tracks/5jaz6aiRknA63NIYWdbr2O',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5jaz6aiRknA63NIYWdbr2O',
#    'duration_ms': 204827,
#    'time_signature': 4}],
#  '7BqBn9nzAq8spo5e7cZ0dJ': [{'danceability': 0.637,
#    'energy': 0.843,
#    'key': 5,
#    'loudness': -5.413,
#    'mode': 1,
#    'speechiness': 0.0432,
#    'acousticness': 0.0151,
#    'instrumentalness': 0,
#    'liveness': 0.0876,
#    'valence': 0.434,
#    'tempo': 109.012,
#    'type': 'audio_features',
#    'id': '7BqBn9nzAq8spo5e7cZ0dJ',
#    'uri': 'spotify:track:7BqBn9nzAq8spo5e7cZ0dJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/7BqBn9nzAq8spo5e7cZ0dJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7BqBn9nzAq8spo5e7cZ0dJ',
#    'duration_ms': 220733,
#    'time_signature': 4}],
#  '6Nz7fcKGTp3gllNtY7abD3': [{'danceability': 0.612,
#    'energy': 0.899,
#    'key': 1,
#    'loudness': -5.098,
#    'mode': 0,
#    'speechiness': 0.029,
#    'acousticness': 0.0168,
#    'instrumentalness': 0.00897,
#    'liveness': 0.362,
#    'valence': 0.684,
#    'tempo': 117.973,
#    'type': 'audio_features',
#    'id': '6Nz7fcKGTp3gllNtY7abD3',
#    'uri': 'spotify:track:6Nz7fcKGTp3gllNtY7abD3',
#    'track_href': 'https://api.spotify.com/v1/tracks/6Nz7fcKGTp3gllNtY7abD3',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Nz7fcKGTp3gllNtY7abD3',
#    'duration_ms': 231347,
#    'time_signature': 4}],
#  '5mmObLga64R1njEbcuh5Mh': [{'danceability': 0.754,
#    'energy': 0.806,
#    'key': 9,
#    'loudness': -4.767,
#    'mode': 1,
#    'speechiness': 0.0388,
#    'acousticness': 0.0346,
#    'instrumentalness': 0.0274,
#    'liveness': 0.204,
#    'valence': 0.532,
#    'tempo': 95.506,
#    'type': 'audio_features',
#    'id': '5mmObLga64R1njEbcuh5Mh',
#    'uri': 'spotify:track:5mmObLga64R1njEbcuh5Mh',
#    'track_href': 'https://api.spotify.com/v1/tracks/5mmObLga64R1njEbcuh5Mh',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5mmObLga64R1njEbcuh5Mh',
#    'duration_ms': 191840,
#    'time_signature': 4}],
#  '7jqzZyJJLrpkRFYGpkqSK6': [{'danceability': 0.552,
#    'energy': 0.643,
#    'key': 0,
#    'loudness': -7.36,
#    'mode': 1,
#    'speechiness': 0.0327,
#    'acousticness': 0.0364,
#    'instrumentalness': 0.74,
#    'liveness': 0.105,
#    'valence': 0.212,
#    'tempo': 120.012,
#    'type': 'audio_features',
#    'id': '7jqzZyJJLrpkRFYGpkqSK6',
#    'uri': 'spotify:track:7jqzZyJJLrpkRFYGpkqSK6',
#    'track_href': 'https://api.spotify.com/v1/tracks/7jqzZyJJLrpkRFYGpkqSK6',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7jqzZyJJLrpkRFYGpkqSK6',
#    'duration_ms': 272800,
#    'time_signature': 4}],
#  '746InuKpJ6tyPac5qvHjW2': [{'danceability': 0.357,
#    'energy': 0.241,
#    'key': 2,
#    'loudness': -12.366,
#    'mode': 1,
#    'speechiness': 0.0618,
#    'acousticness': 0.94,
#    'instrumentalness': 0.000129,
#    'liveness': 0.353,
#    'valence': 0.227,
#    'tempo': 91.195,
#    'type': 'audio_features',
#    'id': '746InuKpJ6tyPac5qvHjW2',
#    'uri': 'spotify:track:746InuKpJ6tyPac5qvHjW2',
#    'track_href': 'https://api.spotify.com/v1/tracks/746InuKpJ6tyPac5qvHjW2',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/746InuKpJ6tyPac5qvHjW2',
#    'duration_ms': 197893,
#    'time_signature': 4}],
#  '3lVoGZoKXQUElnJbU668Jf': [{'danceability': 0.481,
#    'energy': 0.635,
#    'key': 7,
#    'loudness': -4.866,
#    'mode': 1,
#    'speechiness': 0.0246,
#    'acousticness': 0.31,
#    'instrumentalness': 0,
#    'liveness': 0.36,
#    'valence': 0.396,
#    'tempo': 85.043,
#    'type': 'audio_features',
#    'id': '3lVoGZoKXQUElnJbU668Jf',
#    'uri': 'spotify:track:3lVoGZoKXQUElnJbU668Jf',
#    'track_href': 'https://api.spotify.com/v1/tracks/3lVoGZoKXQUElnJbU668Jf',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3lVoGZoKXQUElnJbU668Jf',
#    'duration_ms': 204987,
#    'time_signature': 3}],
#  '2fQxE0jVrjNMT9oJAXtSJR': [{'danceability': 0.758,
#    'energy': 0.557,
#    'key': 7,
#    'loudness': -4.568,
#    'mode': 1,
#    'speechiness': 0.034,
#    'acousticness': 0.0117,
#    'instrumentalness': 0,
#    'liveness': 0.0418,
#    'valence': 0.781,
#    'tempo': 126.986,
#    'type': 'audio_features',
#    'id': '2fQxE0jVrjNMT9oJAXtSJR',
#    'uri': 'spotify:track:2fQxE0jVrjNMT9oJAXtSJR',
#    'track_href': 'https://api.spotify.com/v1/tracks/2fQxE0jVrjNMT9oJAXtSJR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2fQxE0jVrjNMT9oJAXtSJR',
#    'duration_ms': 231840,
#    'time_signature': 4}],
#  '2DjWsDGgL1xNbhnr7f6t5F': [{'danceability': 0.692,
#    'energy': 0.422,
#    'key': 2,
#    'loudness': -10.533,
#    'mode': 1,
#    'speechiness': 0.0333,
#    'acousticness': 0.0811,
#    'instrumentalness': 0,
#    'liveness': 0.0848,
#    'valence': 0.468,
#    'tempo': 74.375,
#    'type': 'audio_features',
#    'id': '2DjWsDGgL1xNbhnr7f6t5F',
#    'uri': 'spotify:track:2DjWsDGgL1xNbhnr7f6t5F',
#    'track_href': 'https://api.spotify.com/v1/tracks/2DjWsDGgL1xNbhnr7f6t5F',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2DjWsDGgL1xNbhnr7f6t5F',
#    'duration_ms': 193120,
#    'time_signature': 4}],
#  '5PKWUDfQFtc5qqo8cs1gQp': [{'danceability': 0.603,
#    'energy': 0.67,
#    'key': 2,
#    'loudness': -3.882,
#    'mode': 0,
#    'speechiness': 0.0249,
#    'acousticness': 0.00408,
#    'instrumentalness': 1.66e-06,
#    'liveness': 0.112,
#    'valence': 0.445,
#    'tempo': 107.995,
#    'type': 'audio_features',
#    'id': '5PKWUDfQFtc5qqo8cs1gQp',
#    'uri': 'spotify:track:5PKWUDfQFtc5qqo8cs1gQp',
#    'track_href': 'https://api.spotify.com/v1/tracks/5PKWUDfQFtc5qqo8cs1gQp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5PKWUDfQFtc5qqo8cs1gQp',
#    'duration_ms': 242974,
#    'time_signature': 4}],
#  '3oDFtOhcN08qeDPAK6MEQG': [{'danceability': 0.867,
#    'energy': 0.857,
#    'key': 9,
#    'loudness': -5.892,
#    'mode': 1,
#    'speechiness': 0.0663,
#    'acousticness': 0.13,
#    'instrumentalness': 0.00171,
# ...
#    'instrumentalness': 0.000504,
#    'liveness': 0.37,
#    'valence': 0.676,
#    'tempo': 94.997,
#    'type': 'audio_features',
#    'id': '3nSiB5WCF2pmRQrYSsteHv',
#    'uri': 'spotify:track:3nSiB5WCF2pmRQrYSsteHv',
#    'track_href': 'https://api.spotify.com/v1/tracks/3nSiB5WCF2pmRQrYSsteHv',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3nSiB5WCF2pmRQrYSsteHv',
#    'duration_ms': 204507,
#    'time_signature': 4}],
#  '62EsBz11VlUwSu3jFy7Rlo': [{'danceability': 0.634,
#    'energy': 0.737,
#    'key': 0,
#    'loudness': -5.732,
#    'mode': 1,
#    'speechiness': 0.03,
#    'acousticness': 0.113,
#    'instrumentalness': 0.000427,
#    'liveness': 0.114,
#    'valence': 0.27,
#    'tempo': 89.994,
#    'type': 'audio_features',
#    'id': '62EsBz11VlUwSu3jFy7Rlo',
#    'uri': 'spotify:track:62EsBz11VlUwSu3jFy7Rlo',
#    'track_href': 'https://api.spotify.com/v1/tracks/62EsBz11VlUwSu3jFy7Rlo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/62EsBz11VlUwSu3jFy7Rlo',
#    'duration_ms': 249573,
#    'time_signature': 4}],
#  '0CpQCN7nEz6tH6THwcJdzw': [{'danceability': 0.478,
#    'energy': 0.595,
#    'key': 0,
#    'loudness': -6.772,
#    'mode': 1,
#    'speechiness': 0.028,
#    'acousticness': 0.053,
#    'instrumentalness': 4.1e-05,
#    'liveness': 0.159,
#    'valence': 0.424,
#    'tempo': 139.808,
#    'type': 'audio_features',
#    'id': '0CpQCN7nEz6tH6THwcJdzw',
#    'uri': 'spotify:track:0CpQCN7nEz6tH6THwcJdzw',
#    'track_href': 'https://api.spotify.com/v1/tracks/0CpQCN7nEz6tH6THwcJdzw',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0CpQCN7nEz6tH6THwcJdzw',
#    'duration_ms': 215533,
#    'time_signature': 4}],
#  '5iyqqccidB1SEpOXXctyTR': [{'danceability': 0.397,
#    'energy': 0.331,
#    'key': 5,
#    'loudness': -9.027,
#    'mode': 1,
#    'speechiness': 0.0297,
#    'acousticness': 0.708,
#    'instrumentalness': 1.37e-06,
#    'liveness': 0.424,
#    'valence': 0.247,
#    'tempo': 78.702,
#    'type': 'audio_features',
#    'id': '5iyqqccidB1SEpOXXctyTR',
#    'uri': 'spotify:track:5iyqqccidB1SEpOXXctyTR',
#    'track_href': 'https://api.spotify.com/v1/tracks/5iyqqccidB1SEpOXXctyTR',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5iyqqccidB1SEpOXXctyTR',
#    'duration_ms': 196347,
#    'time_signature': 4}],
#  '2ihCaVdNZmnHZWt0fvAM7B': [{'danceability': 0.457,
#    'energy': 0.757,
#    'key': 1,
#    'loudness': -5.177,
#    'mode': 1,
#    'speechiness': 0.032,
#    'acousticness': 0.0206,
#    'instrumentalness': 0,
#    'liveness': 0.146,
#    'valence': 0.417,
#    'tempo': 102.961,
#    'type': 'audio_features',
#    'id': '2ihCaVdNZmnHZWt0fvAM7B',
#    'uri': 'spotify:track:2ihCaVdNZmnHZWt0fvAM7B',
#    'track_href': 'https://api.spotify.com/v1/tracks/2ihCaVdNZmnHZWt0fvAM7B',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ihCaVdNZmnHZWt0fvAM7B',
#    'duration_ms': 266600,
#    'time_signature': 4}],
#  '1hxq7kWQnwdhxgpEugBMGk': [{'danceability': 0.359,
#    'energy': 0.648,
#    'key': 3,
#    'loudness': -7.06,
#    'mode': 1,
#    'speechiness': 0.035,
#    'acousticness': 0.108,
#    'instrumentalness': 0.0135,
#    'liveness': 0.0555,
#    'valence': 0.133,
#    'tempo': 111.733,
#    'type': 'audio_features',
#    'id': '1hxq7kWQnwdhxgpEugBMGk',
#    'uri': 'spotify:track:1hxq7kWQnwdhxgpEugBMGk',
#    'track_href': 'https://api.spotify.com/v1/tracks/1hxq7kWQnwdhxgpEugBMGk',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1hxq7kWQnwdhxgpEugBMGk',
#    'duration_ms': 278373,
#    'time_signature': 4}],
#  '60ZGteAEtPCnGE6zevgUcd': [{'danceability': 0.379,
#    'energy': 0.879,
#    'key': 1,
#    'loudness': -4.336,
#    'mode': 0,
#    'speechiness': 0.0362,
#    'acousticness': 0.0421,
#    'instrumentalness': 0.00449,
#    'liveness': 0.146,
#    'valence': 0.37,
#    'tempo': 102.021,
#    'type': 'audio_features',
#    'id': '60ZGteAEtPCnGE6zevgUcd',
#    'uri': 'spotify:track:60ZGteAEtPCnGE6zevgUcd',
#    'track_href': 'https://api.spotify.com/v1/tracks/60ZGteAEtPCnGE6zevgUcd',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/60ZGteAEtPCnGE6zevgUcd',
#    'duration_ms': 211453,
#    'time_signature': 4}],
#  '51gJTJ1l7OCWHjGvfiZ177': [{'danceability': 0.582,
#    'energy': 0.763,
#    'key': 0,
#    'loudness': -7.288,
#    'mode': 1,
#    'speechiness': 0.0308,
#    'acousticness': 0.00228,
#    'instrumentalness': 0.000332,
#    'liveness': 0.101,
#    'valence': 0.327,
#    'tempo': 132.178,
#    'type': 'audio_features',
#    'id': '51gJTJ1l7OCWHjGvfiZ177',
#    'uri': 'spotify:track:51gJTJ1l7OCWHjGvfiZ177',
#    'track_href': 'https://api.spotify.com/v1/tracks/51gJTJ1l7OCWHjGvfiZ177',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/51gJTJ1l7OCWHjGvfiZ177',
#    'duration_ms': 243520,
#    'time_signature': 4}],
#  '1cq5GZvosXfPaUdHGsBAUS': [{'danceability': 0.565,
#    'energy': 0.916,
#    'key': 7,
#    'loudness': -4.768,
#    'mode': 1,
#    'speechiness': 0.0562,
#    'acousticness': 0.0104,
#    'instrumentalness': 1.53e-06,
#    'liveness': 0.0844,
#    'valence': 0.599,
#    'tempo': 118.012,
#    'type': 'audio_features',
#    'id': '1cq5GZvosXfPaUdHGsBAUS',
#    'uri': 'spotify:track:1cq5GZvosXfPaUdHGsBAUS',
#    'track_href': 'https://api.spotify.com/v1/tracks/1cq5GZvosXfPaUdHGsBAUS',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1cq5GZvosXfPaUdHGsBAUS',
#    'duration_ms': 222680,
#    'time_signature': 4}],
#  '5SSr61qhwOcC1elvF0eB3C': [{'danceability': 0.648,
#    'energy': 0.979,
#    'key': 8,
#    'loudness': -3.609,
#    'mode': 1,
#    'speechiness': 0.0795,
#    'acousticness': 0.00851,
#    'instrumentalness': 0.131,
#    'liveness': 0.285,
#    'valence': 0.444,
#    'tempo': 105.475,
#    'type': 'audio_features',
#    'id': '5SSr61qhwOcC1elvF0eB3C',
#    'uri': 'spotify:track:5SSr61qhwOcC1elvF0eB3C',
#    'track_href': 'https://api.spotify.com/v1/tracks/5SSr61qhwOcC1elvF0eB3C',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5SSr61qhwOcC1elvF0eB3C',
#    'duration_ms': 192200,
#    'time_signature': 4}],
#  '3bnVBN67NBEzedqQuWrpP4': [{'danceability': 0.655,
#    'energy': 0.632,
#    'key': 2,
#    'loudness': -4.802,
#    'mode': 1,
#    'speechiness': 0.0489,
#    'acousticness': 0.0189,
#    'instrumentalness': 0,
#    'liveness': 0.0722,
#    'valence': 0.447,
#    'tempo': 120.113,
#    'type': 'audio_features',
#    'id': '3bnVBN67NBEzedqQuWrpP4',
#    'uri': 'spotify:track:3bnVBN67NBEzedqQuWrpP4',
#    'track_href': 'https://api.spotify.com/v1/tracks/3bnVBN67NBEzedqQuWrpP4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3bnVBN67NBEzedqQuWrpP4',
#    'duration_ms': 188493,
#    'time_signature': 4}],
#  '5cbpoIu3YjoOwbBDGUEp3P': [{'danceability': 0.766,
#    'energy': 0.519,
#    'key': 9,
#    'loudness': -7.355,
#    'mode': 0,
#    'speechiness': 0.0366,
#    'acousticness': 0.098,
#    'instrumentalness': 0,
#    'liveness': 0.0855,
#    'valence': 0.612,
#    'tempo': 129.972,
#    'type': 'audio_features',
#    'id': '5cbpoIu3YjoOwbBDGUEp3P',
#    'uri': 'spotify:track:5cbpoIu3YjoOwbBDGUEp3P',
#    'track_href': 'https://api.spotify.com/v1/tracks/5cbpoIu3YjoOwbBDGUEp3P',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5cbpoIu3YjoOwbBDGUEp3P',
#    'duration_ms': 267720,
#    'time_signature': 4}],
#  '1s9xuJxhYM0LdVqksjegcg': [{'danceability': 0.715,
#    'energy': 0.723,
#    'key': 6,
#    'loudness': -5.993,
#    'mode': 0,
#    'speechiness': 0.0569,
#    'acousticness': 0.0396,
#    'instrumentalness': 8.57e-05,
#    'liveness': 0.084,
#    'valence': 0.479,
#    'tempo': 114.985,
#    'type': 'audio_features',
#    'id': '1s9xuJxhYM0LdVqksjegcg',
#    'uri': 'spotify:track:1s9xuJxhYM0LdVqksjegcg',
#    'track_href': 'https://api.spotify.com/v1/tracks/1s9xuJxhYM0LdVqksjegcg',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1s9xuJxhYM0LdVqksjegcg',
#    'duration_ms': 207160,
#    'time_signature': 4}],
#  '5xlS0QkVrSH7ssEbBgBzbM': [{'danceability': 0.602,
#    'energy': 0.553,
#    'key': 11,
#    'loudness': -9.336,
#    'mode': 1,
#    'speechiness': 0.0328,
#    'acousticness': 0.108,
#    'instrumentalness': 0,
#    'liveness': 0.0512,
#    'valence': 0.971,
#    'tempo': 130.594,
#    'type': 'audio_features',
#    'id': '5xlS0QkVrSH7ssEbBgBzbM',
#    'uri': 'spotify:track:5xlS0QkVrSH7ssEbBgBzbM',
#    'track_href': 'https://api.spotify.com/v1/tracks/5xlS0QkVrSH7ssEbBgBzbM',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5xlS0QkVrSH7ssEbBgBzbM',
#    'duration_ms': 118840,
#    'time_signature': 4}],
#  '6VojZJpMyuKClbwyilWlQj': [{'danceability': 0.385,
#    'energy': 0.657,
#    'key': 5,
#    'loudness': -6.975,
#    'mode': 1,
#    'speechiness': 0.0342,
#    'acousticness': 0.724,
#    'instrumentalness': 0,
#    'liveness': 0.105,
#    'valence': 0.672,
#    'tempo': 124.895,
#    'type': 'audio_features',
#    'id': '6VojZJpMyuKClbwyilWlQj',
#    'uri': 'spotify:track:6VojZJpMyuKClbwyilWlQj',
#    'track_href': 'https://api.spotify.com/v1/tracks/6VojZJpMyuKClbwyilWlQj',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6VojZJpMyuKClbwyilWlQj',
#    'duration_ms': 153867,
#    'time_signature': 4}],
#  '5t9KYe0Fhd5cW6UYT4qP8f': [{'danceability': 0.396,
#    'energy': 0.473,
#    'key': 10,
#    'loudness': -7.67,
#    'mode': 0,
#    'speechiness': 0.0345,
#    'acousticness': 0.326,
#    'instrumentalness': 0.000124,
#    'liveness': 0.109,
#    'valence': 0.385,
#    'tempo': 133.449,
#    'type': 'audio_features',
#    'id': '5t9KYe0Fhd5cW6UYT4qP8f',
#    'uri': 'spotify:track:5t9KYe0Fhd5cW6UYT4qP8f',
#    'track_href': 'https://api.spotify.com/v1/tracks/5t9KYe0Fhd5cW6UYT4qP8f',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5t9KYe0Fhd5cW6UYT4qP8f',
#    'duration_ms': 219027,
#    'time_signature': 4}],
#  '0shGCs5AkhwJIgUb0SSz2B': [{'danceability': 0.589,
#    'energy': 0.369,
#    'key': 5,
#    'loudness': -8.678,
#    'mode': 0,
#    'speechiness': 0.0321,
#    'acousticness': 0.855,
#    'instrumentalness': 0,
#    'liveness': 0.352,
#    'valence': 0.529,
#    'tempo': 132.954,
#    'type': 'audio_features',
#    'id': '0shGCs5AkhwJIgUb0SSz2B',
#    'uri': 'spotify:track:0shGCs5AkhwJIgUb0SSz2B',
#    'track_href': 'https://api.spotify.com/v1/tracks/0shGCs5AkhwJIgUb0SSz2B',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0shGCs5AkhwJIgUb0SSz2B',
#    'duration_ms': 201200,
#    'time_signature': 4}],
#  '52VHBrro7AEMJDpgmg2K6L': [{'danceability': 0.547,
#    'energy': 0.688,
#    'key': 5,
#    'loudness': -5.266,
#    'mode': 1,
#    'speechiness': 0.0441,
#    'acousticness': 0.346,
#    'instrumentalness': 2.33e-05,
#    'liveness': 0.0586,
#    'valence': 0.462,
#    'tempo': 175.909,
#    'type': 'audio_features',
#    'id': '52VHBrro7AEMJDpgmg2K6L',
#    'uri': 'spotify:track:52VHBrro7AEMJDpgmg2K6L',
#    'track_href': 'https://api.spotify.com/v1/tracks/52VHBrro7AEMJDpgmg2K6L',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/52VHBrro7AEMJDpgmg2K6L',
#    'duration_ms': 214627,
#    'time_signature': 4}],
#  '0PjkFSNBbpfYRYpAG4uuGb': [{'danceability': 0.659,
#    'energy': 0.911,
#    'key': 4,
#    'loudness': -2.28,
#    'mode': 1,
#    'speechiness': 0.0786,
#    'acousticness': 0.154,
#    'instrumentalness': 0.000304,
#    'liveness': 0.191,
#    'valence': 0.576,
#    'tempo': 91.999,
#    'type': 'audio_features',
#    'id': '0PjkFSNBbpfYRYpAG4uuGb',
#    'uri': 'spotify:track:0PjkFSNBbpfYRYpAG4uuGb',
#    'track_href': 'https://api.spotify.com/v1/tracks/0PjkFSNBbpfYRYpAG4uuGb',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PjkFSNBbpfYRYpAG4uuGb',
#    'duration_ms': 169866,
#    'time_signature': 4}],
#  '2Yh8cnpddujSLPOVJKlSDt': [{'danceability': 0.492,
#    'energy': 0.78,
#    'key': 9,
#    'loudness': -4.059,
#    'mode': 0,
#    'speechiness': 0.0372,
#    'acousticness': 0.0451,
#    'instrumentalness': 2.41e-05,
#    'liveness': 0.101,
#    'valence': 0.189,
#    'tempo': 139.957,
#    'type': 'audio_features',
#    'id': '2Yh8cnpddujSLPOVJKlSDt',
#    'uri': 'spotify:track:2Yh8cnpddujSLPOVJKlSDt',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Yh8cnpddujSLPOVJKlSDt',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Yh8cnpddujSLPOVJKlSDt',
#    'duration_ms': 184529,
#    'time_signature': 4}],
#  '4cgDk0IjwdG8w1ArIaqdpq': [{'danceability': 0.519,
#    'energy': 0.737,
#    'key': 11,
#    'loudness': -6.451,
#    'mode': 1,
#    'speechiness': 0.0615,
#    'acousticness': 0.00936,
#    'instrumentalness': 7.76e-05,
#    'liveness': 0.378,
#    'valence': 0.763,
#    'tempo': 131.042,
#    'type': 'audio_features',
#    'id': '4cgDk0IjwdG8w1ArIaqdpq',
#    'uri': 'spotify:track:4cgDk0IjwdG8w1ArIaqdpq',
#    'track_href': 'https://api.spotify.com/v1/tracks/4cgDk0IjwdG8w1ArIaqdpq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4cgDk0IjwdG8w1ArIaqdpq',
#    'duration_ms': 214693,
#    'time_signature': 4}],
#  '4Yb6G9OWgGBmfOpxcFxp6P': [{'danceability': 0.571,
#    'energy': 0.519,
#    'key': 1,
#    'loudness': -7.333,
#    'mode': 1,
#    'speechiness': 0.0358,
#    'acousticness': 0.193,
#    'instrumentalness': 4.19e-05,
#    'liveness': 0.103,
#    'valence': 0.343,
#    'tempo': 144.596,
#    'type': 'audio_features',
#    'id': '4Yb6G9OWgGBmfOpxcFxp6P',
#    'uri': 'spotify:track:4Yb6G9OWgGBmfOpxcFxp6P',
#    'track_href': 'https://api.spotify.com/v1/tracks/4Yb6G9OWgGBmfOpxcFxp6P',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Yb6G9OWgGBmfOpxcFxp6P',
#    'duration_ms': 231520,
#    'time_signature': 4}],
#  '0u2W89AQvH3sDVg7UX6YOT': [{'danceability': 0.404,
#    'energy': 0.759,
#    'key': 3,
#    'loudness': -6.097,
#    'mode': 1,
#    'speechiness': 0.0433,
#    'acousticness': 0.612,
#    'instrumentalness': 0.00118,
#    'liveness': 0.136,
#    'valence': 0.173,
#    'tempo': 135.062,
#    'type': 'audio_features',
#    'id': '0u2W89AQvH3sDVg7UX6YOT',
#    'uri': 'spotify:track:0u2W89AQvH3sDVg7UX6YOT',
#    'track_href': 'https://api.spotify.com/v1/tracks/0u2W89AQvH3sDVg7UX6YOT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0u2W89AQvH3sDVg7UX6YOT',
#    'duration_ms': 189160,
#    'time_signature': 3}],
#  '475uLoRnKvvkW7cvlF9U4v': [{'danceability': 0.548,
#    'energy': 0.829,
#    'key': 7,
#    'loudness': -2.154,
#    'mode': 1,
#    'speechiness': 0.0479,
#    'acousticness': 0.139,
#    'instrumentalness': 0,
#    'liveness': 0.0985,
#    'valence': 0.521,
#    'tempo': 80.792,
#    'type': 'audio_features',
#    'id': '475uLoRnKvvkW7cvlF9U4v',
#    'uri': 'spotify:track:475uLoRnKvvkW7cvlF9U4v',
#    'track_href': 'https://api.spotify.com/v1/tracks/475uLoRnKvvkW7cvlF9U4v',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/475uLoRnKvvkW7cvlF9U4v',
#    'duration_ms': 242333,
#    'time_signature': 4}],
#  '1OtWwtGFPXVhdAVKZHwrNF': [{'danceability': 0.474,
#    'energy': 0.343,
#    'key': 7,
#    'loudness': -12.138,
#    'mode': 1,
#    'speechiness': 0.0298,
#    'acousticness': 0.0225,
#    'instrumentalness': 0.00704,
#    'liveness': 0.152,
#    'valence': 0.607,
#    'tempo': 114.877,
#    'type': 'audio_features',
#    'id': '1OtWwtGFPXVhdAVKZHwrNF',
#    'uri': 'spotify:track:1OtWwtGFPXVhdAVKZHwrNF',
#    'track_href': 'https://api.spotify.com/v1/tracks/1OtWwtGFPXVhdAVKZHwrNF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1OtWwtGFPXVhdAVKZHwrNF',
#    'duration_ms': 263973,
#    'time_signature': 4}],
#  '2Bs4jQEGMycglOfWPBqrVG': [{'danceability': 0.536,
#    'energy': 0.768,
#    'key': 10,
#    'loudness': -5.948,
#    'mode': 0,
#    'speechiness': 0.0347,
#    'acousticness': 0.00433,
#    'instrumentalness': 0,
#    'liveness': 0.114,
#    'valence': 0.545,
#    'tempo': 77.217,
#    'type': 'audio_features',
#    'id': '2Bs4jQEGMycglOfWPBqrVG',
#    'uri': 'spotify:track:2Bs4jQEGMycglOfWPBqrVG',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Bs4jQEGMycglOfWPBqrVG',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Bs4jQEGMycglOfWPBqrVG',
#    'duration_ms': 228133,
#    'time_signature': 4}],
#  '7kSLdGdXLey7pzLsWpdg1h': [{'danceability': 0.707,
#    'energy': 0.222,
#    'key': 7,
#    'loudness': -11.716,
#    'mode': 1,
#    'speechiness': 0.0329,
#    'acousticness': 0.788,
#    'instrumentalness': 0,
#    'liveness': 0.205,
#    'valence': 0.556,
#    'tempo': 110.095,
#    'type': 'audio_features',
#    'id': '7kSLdGdXLey7pzLsWpdg1h',
#    'uri': 'spotify:track:7kSLdGdXLey7pzLsWpdg1h',
#    'track_href': 'https://api.spotify.com/v1/tracks/7kSLdGdXLey7pzLsWpdg1h',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7kSLdGdXLey7pzLsWpdg1h',
#    'duration_ms': 219640,
#    'time_signature': 4}],
#  ...}
